# %% [markdown]
# # Problem 1

# %% [markdown]
# We have the function, $\mathrm{f\left(x_{1},x_{2}\right)=2x_{1}^{2}-4x_{1}x_{2}+1.5x_{2}^{2}+x_{2}}$
#
# We first calculate the gradient and the Hessian,
#
# $\mathrm{\nabla f\left(x_{1},x_{2}\right)=\begin{bmatrix}\frac{\partial f}{\partial x_{1}}\\
# \frac{\partial f}{\partial x_{2}}
# \end{bmatrix}=\begin{bmatrix}4x_{1}-4x_{2}+0+0\\
# 0-4x_{1}+3x_{2}+1
# \end{bmatrix}=\begin{bmatrix}4x_{1}-4x_{2}\\
# -4x_{1}+3x_{2}+1
# \end{bmatrix}}$
#
# $\mathrm{H\left(x_{1},x_{2}\right)=\begin{bmatrix}\frac{\partial^{2}f}{\partial x_{1}^{2}} & \frac{\partial^{2}f}{\partial x_{1}\partial x_{2}}\\
# \frac{\partial^{2}f}{\partial x_{2}\partial x_{1}} & \frac{\partial^{2}f}{\partial x_{2}^{2}}
# \end{bmatrix}=\begin{bmatrix}4-0 & 0-4\\
# -4+0+0 & 0+3+0
# \end{bmatrix}=\begin{bmatrix}4 & -4\\
# -4 & 3
# \end{bmatrix}}$
#
# To find the stationary point, we set the gradient equal to zero and solve for $\mathrm{x_{1}}$ and $\mathrm{x_{2}}$,
#
# $\mathrm{\nabla f\left(x_{1},x_{2}\right)=\begin{bmatrix}4x_{1}-4x_{2}\\
# -4x_{1}+3x_{2}
# \end{bmatrix}=\begin{bmatrix}0\\
# -1
# \end{bmatrix}}$
# From visual inspection, the stationary point is,
# $\mathrm{x_{1}=1}$ and $\mathrm{x_{2}=1}$
#
# To show that this is a saddle point, we need to determine the eigenvalues of the Hessian.
#
# $\mathrm{\left|H\left(x_{1},x_{2}\right)-\lambda I\right|=0}$
#
# $\mathrm{\Rightarrow\begin{vmatrix}4-\lambda & -4\\
# -4 & 3-\lambda
# \end{vmatrix}=0}$
#
# $\mathrm{\Rightarrow\left(4-\lambda\right)\left(3-\lambda\right)-16=0\Longrightarrow12-4\lambda-3\lambda+\lambda^{2}-16=0}$
#
# $\mathrm{\Rightarrow\lambda^{2}-7\lambda-4=0}$
#
# Using the quadratic formula we get,
#
# $\mathrm{\lambda_{1}=\frac{7+\sqrt{7^{2}-4(1)(-4)}}{2(1)}=\frac{1}{2}\left(7+\sqrt{49+16}\right)=\frac{1}{2}\left(7+\sqrt{65}\right)\approx7.5311}$
#
# $\mathrm{\lambda_{2}=\frac{7-\sqrt{7^{2}-4(1)(-4)}}{2(1)}=\frac{1}{2}\left(7-\sqrt{65}\right)\approx-0.5311}$
#
# We have both a positive and negative eigenvalues, therefore this Hessian is an indefinite matrix. One direction curves up with the positive eigenvalue while the other curves down with the negative eigenvalue. Therefore, this is a saddle point.
#
# Taylor-Series expansion:
#
# $\mathrm{f\left(x_{1},x_{2}\right)\approx f\left(x_{0}\right)+\left.\nabla_{x}f\left(x\right)\right|_{x_{0}}^{T}\left(x-x_{0}\right)+\frac{1}{2}\left(x-x_{0}\right)^{T}\left.H\left(x_{1},x_{2}\right)\right|_{x_{0}}\left(x-x_{0}\right)}$
#
# At $\mathrm{x_{1}=1}$ and $\mathrm{x_{2}=1}$
#
# $\mathrm{f\left(x_{1},x_{2}\right)\approx f\left(1,1\right)+\begin{bmatrix}4x_{1}-4x_{2}\\
# -4x_{1}+3x_{2}+1
# \end{bmatrix}^{T}\begin{bmatrix}x_{1}-1\\
# x_{2}-1
# \end{bmatrix}+\frac{1}{2}\begin{bmatrix}x_{1}-1\\
# x_{2}-1
# \end{bmatrix}^{T}\begin{bmatrix}4 & -4\\
# -4 & 3
# \end{bmatrix}\begin{bmatrix}x_{1}-1\\
# x_{2}-1
# \end{bmatrix}}$
#
# $\mathrm{\Rightarrow f\left(x_{1},x_{2}\right)\approx f\left(1,1\right)+\begin{bmatrix}4\left(1\right)-4\left(1\right)\\
# -4\left(1\right)+3\left(1\right)+1
# \end{bmatrix}^{T}\begin{bmatrix}x_{1}-1\\
# x_{2}-1
# \end{bmatrix}+\frac{1}{2}\begin{bmatrix}x_{1}-1\\
# x_{2}-1
# \end{bmatrix}^{T}\begin{bmatrix}4 & -4\\
# -4 & 3
# \end{bmatrix}\begin{bmatrix}x_{1}-1\\
# x_{2}-1
# \end{bmatrix}}$
#
# $\mathrm{\Rightarrow f\left(x_{1},x_{2}\right)\approx f\left(1,1\right)+\begin{bmatrix}0\\
# 0
# \end{bmatrix}^{T}\begin{bmatrix}x_{1}-1\\
# x_{2}-1
# \end{bmatrix}+\frac{1}{2}\begin{bmatrix}x_{1}-1\\
# x_{2}-1
# \end{bmatrix}^{T}\begin{bmatrix}4 & -4\\
# -4 & 3
# \end{bmatrix}\begin{bmatrix}x_{1}-1\\
# x_{2}-1
# \end{bmatrix}}$
#
# $\mathrm{\Rightarrow f\left(x_{1},x_{2}\right)\approx f\left(1,1\right)+\frac{1}{2}\begin{bmatrix}x_{1}-1 & x_{2}-1\end{bmatrix}\begin{bmatrix}4 & -4\\
# -4 & 3
# \end{bmatrix}\begin{bmatrix}x_{1}-1\\
# x_{2}-1
# \end{bmatrix}}$
#
# $\mathrm{\Rightarrow f\left(x_{1},x_{2}\right)\approx f\left(1,1\right)+\frac{1}{2}\begin{bmatrix}4x_{1}-4x_{2} & -4x_{1}+3x_{2}+1\end{bmatrix}\begin{bmatrix}x_{1}-1\\
# x_{2}-1
# \end{bmatrix}}$
#
# $\mathrm{\Rightarrow f\left(x_{1},x_{2}\right)\approx f\left(1,1\right)+\frac{1}{2}\left[\left(4x_{1}-4x_{2}\right)\left(x_{1}-1\right)+\left(-4x_{1}+3x_{2}+1\right)\left(x_{2}-1\right)\right]}$
#
# Expanding this out, we get,
#
# $\mathrm{\Rightarrow f\left(x_{1},x_{2}\right)-f\left(1,1\right)\approx \frac{1}{2}\left[4x_{1}^{2}-4x_{1}-4x_{1}x_{2}+4x_{2}-4x_{1}x_{2}+4x_{1}+3x_{2}^{2}-3x_{2}+x_{2}-1\right]}$
#
# $\mathrm{\Rightarrow2x_{1}^{2}+1.5x_{2}^{2}-4x_{1}x_{2}+x_{2}-0.5}$
#
# We are looking for $\mathrm{f\left(x_{1},x_{2}\right)<0}$, so we can start by setting our function equal to zero, giving,
#
# $\mathrm{f\left(x_{1},x_{2}\right)-f\left(1,1\right)\approx2x_{1}^{2}+1.5x_{2}^{2}-4x_{1}x_{2}+x_{2}-0.5=0}$
#
# We can divide by $\mathrm{x_{2}^{2}}$, which gives,
#
# $\mathrm{\Rightarrow2\frac{x_{1}^{2}}{x_{2}^{2}}+1.5-4\frac{x_{1}}{x_{2}}+1-0.5=0}$
#
# Let $\mathrm{u\equiv\frac{x_{1}}{x_{2}}}$, then,
#
# $\mathrm{\Rightarrow2u^{2}-4u+2=0}$
#
# If we define $\mathrm{u_{1}}$ and $\mathrm{u_{2}}$ as the roots to this quadratic function, then the L.H.S. can be expressed as,
#
# $\mathrm{\left(u-u_{1}\right)\left(u-u_{2}\right)=0}$
#
# Thus,
#
# $\mathrm{f\left(x_{1},x_{2}\right)-f\left(1,1\right)\approx\left(u-u_{1}\right)\left(u-u_{2}\right)=0}$
#
# Expanding out and substituting back in for u, gives,
#
# $\mathrm{u^{2}-uu_{1}-uu_{2}+u_{1}u_{2}=0}$
#
# $\mathrm{\Rightarrow\frac{x_{1}^{2}}{x_{2}^{2}}-u_{1}\frac{x_{1}}{x_{2}}-u_{2}\frac{x_{1}}{x_{2}}+u_{1}u_{2}=0}$
#
# Multiplying by $\mathrm{x_{2}^{2}}$,
#
# $\mathrm{x_{1}^{2}-u_{1}x_{1}x_{2}-u_{2}x_{1}x_{2}+u_{1}u_{2}x_{2}^{2}=0}$
#
# $\mathrm{\Rightarrow x_{1}^{2}-\left(u_{1}+u_{2}\right)x_{1}x_{2}+u_{1}u_{2}x_{2}^{2}=0}$
#
# Factoring this again gives,
#
# $\mathrm{\left(x_{1}-u_{1}x_{2}\right)\left(x_{1}-u_{2}x_{2}\right)=0}$
#
# Thus,
#
# $\mathrm{f\left(x_{1},x_{2}\right)-f\left(1,1\right)\approx\left(x_{1}-u_{1}x_{2}\right)\left(x_{1}-u_{2}x_{2}\right)<0}$
#
# Referring back to our polynomial equation of u, we had,
#
# $\mathrm{2u^{2}-4u+2=0}$
#
# $\mathrm{u_{1}}$ and $\mathrm{u_{2}}$ are the solutions to this equation. So solving for $\mathrm{u_{1}}$ and $\mathrm{u_{2}}$ gives,
#
# $\mathrm{u^{2}-2u+1=0\Longrightarrow\left(u-1\right)\left(u-1\right)=0}$
#
# Thus,
#
# $\mathrm{u_{1}=1}$ and $\mathrm{u_{2}=1}$
#
# Substituting this values back into our Taylor series function gives,
#
# $\mathrm{f\left(x_{1},x_{2}\right)-f\left(1,1\right)\approx\left(x_{1}-x_{2}\right)\left(x_{1}-x_{2}\right)<0}$

# %% [markdown]
# # Problem 2

# %% [markdown]
# ### a)

# %% [markdown]
# Given the plane $\mathrm{x_{1}+2x_{2}+3x_{3}=1}$, we can setup an unconstrained optimzation problem as the following.
#
# $\mathrm{min\;\;\left\Vert x-x_{0}\right\Vert ^{2}}$
#
# Where,
#
# $\mathrm{x_{0}}=\begin{bmatrix}-1\\
# 0\\
# 1
# \end{bmatrix}$
#
# To turn this into an unconstrained optimziation problem, we can express our optimization function f(x) as a function of $\mathrm{x_{2}}$ and $\mathrm{x_{3}}$ only. This is done by rearranging the equation of the plane to solve for $\mathrm{x_{1}}$
#
# $\mathrm{x_{1}=-2x_{2}-3x_{3}+1}$
#
# Substituting this into our optimization function, we have,
#
# $\mathrm{f\left(x\right)=\left\Vert x-x_{0}\right\Vert ^{2}=\left(x_{1}-x_{0}\right)^{2}+\left(x_{2}-x_{0}\right)^{2}+\left(x_{3}-x_{0}\right)^{2}}$
# $\mathrm{\Rightarrow\left(-2x_{2}-3x_{3}+1-x_{0}\right)^{2}+\left(x_{2}-x_{0}\right)^{2}+\left(x_{3}-x_{0}\right)^{2}}$
#
# Then we can substitute in the values of $\mathrm{x_{0}}$,
#
# $\mathrm{f\left(x\right)=\left(-2x_{2}-3x_{3}+2\right)^{2}+x_{2}^{2}+\left(x_{3}-1\right)^{2}}$
#
# Expanding out and combining terms, our optimization function becomes,
#
# $\mathrm{f\left(x\right)=\left(-2x_{2}-3x_{3}+2\right)\left(-2x_{2}-3x_{3}+2\right)+x_{2}^{2}+\left(x_{3}-1\right)\left(x_{3}-1\right)}$
#
# $\mathrm{\Rightarrow\;=4x_{2}^{2}+12x_{2}x_{3}-8x_{2}+9x_{3}^{2}-12x_{3}+4+x_{2}^{2}+x_{3}^{2}-2x_{3}+1}$
#
# $\mathrm{\Rightarrow\;f\left(x\right)=5x_{2}^{2}+10x_{3}^{2}+12x_{2}x_{3}-8x_{2}-14x_{3}+5}$
#
# **Thus our unconstrained optimization problem becomes,**
#
# $\mathrm{min:\;\;f\left(x\right)}$
#
# Where,
#
# $\mathrm{f\left(x\right)=5x_{2}^{2}+10x_{3}^{2}+12x_{2}x_{3}-8x_{2}-14x_{3}+5}$
#
# $\mathrm{x_{1}=-2x_{2}-3x_{3}+1}$
#
# This problem is strictly convex. This can be found by looking at the Hessian. First, we find the gradient. Then we calculate the Hessian,
#
# $\mathrm{\nabla_{x}f\left(x\right)=\begin{bmatrix}\frac{\partial f}{\partial x_{2}}\\
# \frac{\partial f}{\partial x_{3}}
# \end{bmatrix}=\begin{bmatrix}10x_{2}+12x_{3}-8\\
# 20x_{3}+12x_{2}-14
# \end{bmatrix}}$
#
# $\mathrm{H\left(x\right)=\begin{bmatrix}\frac{\partial^{2}f}{\partial x_{2}^{2}} & \frac{\partial^{2}f}{\partial x_{2}\partial x_{3}}\\
# \frac{\partial^{2}f}{\partial x_{3}\partial x_{2}} & \frac{\partial^{2}f}{\partial x_{3}^{2}}
# \end{bmatrix}=\begin{bmatrix}10 & 12\\
# 12 & 20
# \end{bmatrix}}$
#
# Next, we need to determine the eigenvalues of the Hessian. Determining the characteristic polynomial and then solving it for eigenvalues, gives,
#
# $\mathrm{\left|H-\lambda I\right|=0\Longrightarrow\begin{vmatrix}10-\lambda & 12\\
# 12 & 20-\lambda
# \end{vmatrix}=\left(10-\lambda\right)\left(20-\lambda\right)-\left(12\right)\left(12\right)=200-30\lambda+\lambda^{2}-144=\lambda^{2}-30\lambda+56}$
#
# $\mathrm{\lambda^{2}-30\lambda+56=0\Longrightarrow\left(\lambda-28\right)\left(\lambda-2\right)=0}$
#
# $\mathrm{\lambda_{1}=28}$ and $\mathrm{\lambda_{2}=2}$
#
# Since all of our eigenvalues are greater than zero, this Hessian is p.d. Further, because this Hessian is constant, it will be p.d. everywhere, thus making our optimization function strictly convex. Also, since there are no constraints, we do not need to check if they are convex. Therefore, this optimzation problem is strictly convex.

# %% [markdown]
# ### b)

# %%
# MAE 598 - Design Optimization HW # 2
# Benjamin Webb
# 9/16/2022

import numpy as np
import matplotlib.pyplot as plt


def gradx(x):
	# Calculates gradient for problem 2
	# given input vector x and x0
	# x = current point

	g = np.zeros((2, 1))
	g[0] = 10*x[0] + 12*x[1] - 8.0
	g[1] = 20*x[1] + 12*x[0] - 14.0

	return g


def hessian():
	# Generates Hessian for problem 2
	# Hessian is constant for this problem

	H = np.array([[10.0, 12.0], [12.0, 20.0]])

	return H


def GD_inexact(t, alpha, x0, epsilon0):
	# Performs gradient desecent using inexact line search for problem 2
	# t: tuning parameter between (0, 1)
	# alpha: initial step-size
	# x0: initial starting point
	# epsilon0: stopping criteria

	# Initialize stopping critera
	epsilon = np.zeros((1000, 1))
	epsilon[0] = 1.0
	n = np.uint16(0)

	# Begin gradient descent loop
	while epsilon[n] > epsilon0:
		# Problem 2 minimize function ||x - x0||^2
		f0 = 5.0*x0[0]**2 + 10.0*x0[1]**2 + 12.0*x0[0]*x0[1] - 8.0*x0[0] - 14.0*x0[1] + 5.0

		# Calculate gradient at current point
		g0 = gradx(x0)

		# Calculate f(x - alpha*g0)
		x = x0 - alpha*g0
		f = 5.0*x[0]**2 + 10.0*x[1]**2 + 12.0*x[0]*x[1] - 8.0*x[0] - 14.0*x[1] + 5.0

		# Calculate Phi(alpha) = f0 - t*g0^T*g0*alpha
		phi = f0 - t * g0.T @ g0 * alpha

		# Determine how to proceed to next step
		if np.abs(f) > np.abs(phi):
			# Update alpha
			alpha = 0.5 * alpha
		elif n >= 1000:
			break
		else:
			n = n + np.uint16(1)
			epsilon[n] = np.linalg.norm(f - f0)
			x0 = x
			alpha = 1.0

	# Print complete statement with # of iterations
	print('Gradient Descent Optimization Complete')
	print('# of Iterations: ' + str(n))
	return x, n, epsilon[1:n+1]

def newton(x0, epsilon0):
	# Function performs Newton's method for optimization of problem 2
	# x0: initial guess
	# epsilon0: stopping criteria

	# Initialize stopping criteria
	epsilon = np.zeros((1000, 1))
	epsilon[0] = 1.0
	n = np.uint16(0)

	# Calculate Hessian once, since it is constant over domain of this function
	H0 = hessian()
	H0_1 = np.linalg.inv(H0)

	# Begin optimization loop
	while epsilon[n] > epsilon0:
		# Problem 2 optimzation function
		f0 = 5.0*x0[0]**2 + 10.0*x0[1]**2 + 12.0*x0[0]*x0[1] - 8.0*x0[0] - 14.0*x0[1] + 5.0

		# Calculate gradient at current point
		g0 = gradx(x0)

		# Calculate next x values
		x = x0 - H0_1 @ g0

		# Update optimization function value
		f = f0 - 0.5*g0.T @ H0_1 @ g0

		# Update stoping criteria and determine next step
		n = n + np.uint16(1)
		epsilon[n] = np.linalg.norm(f - f0)
		x0 = x
		if n >= 1000:
			break

	# Print complete statement with # of iterations
	print('Newton Optimization Complete')
	print('# of Iterations: ' + str(n))
	return x, n, epsilon[1:n+1]


# Main program for problem 2
if __name__ == '__main__':
	# HW2 Problem 2

	# Gradient descent w/ inexact line search with t = 1.0
	x_GD, n_GD, eps_GD = GD_inexact(1.0, 1.0, np.array([[10.0], [10.0]]), 0.000001)
	x1_GD = -2.0*x_GD[0] - 3.0*x_GD[1] + 1

	print('t = ' + str(1.0))
	print('x1 = ' + str(x1_GD))
	print('x2 = ' + str(x_GD[0]))
	print('x3 = ' + str(x_GD[1]))

	# Newton's method
	x_N, n_N, eps_N = newton(np.array([[10.0], [10.0]]), 0.000001)
	x1_N = -2.0*x_N[0] - 3.0*x_N[1] + 1

	print('x1 = ' + str(x1_N))
	print('x2 = ' + str(x_N[0]))
	print('x3 = ' + str(x_N[1]))

	# Compare solutions of each method
	# Determine distance of each solution to desired point (-1, 0, 1)^T
	d_GD = np.sqrt((x1_GD + 1.0)**2 + x_GD[0]**2 + (x_GD[1] - 1.0)**2)
	d_N = np.sqrt((x1_N + 1.0)**2 + x_N[0]**2 + (x_N[1] - 1.0)**2)
	print(' ')
	print('Gradient Descent Distance = ' + str(d_GD))
	print('Newtons Method Distance = ' + str(d_N))
	print(' ')

	# Plot method convergence
	fig = plt.figure(num=1)
	plt.semilogy(np.linspace(1, n_GD, n_GD), eps_GD, 'bD--', np.linspace(1, n_N, n_N), eps_N, 'rD--')
	plt.grid(b=True, which='both', axis='y')
	plt.title('t = 1.0')
	plt.ylabel('error')
	plt.xlabel('# of Iterations')
	fig.legend(['Gradient Descent', 'Newtons Method'])

	# Gradient descent w/ inexact line search with t = 0.5
	x_GD, n_GD, eps_GD = GD_inexact(0.5, 1.0, np.array([[10.0], [10.0]]), 0.000001)
	x1_GD = -2.0 * x_GD[0] - 3.0 * x_GD[1] + 1

	print('t = ' + str(0.5))
	print('x1 = ' + str(x1_GD))
	print('x2 = ' + str(x_GD[0]))
	print('x3 = ' + str(x_GD[1]))

	# Determine distance of each solution to desired point (-1, 0, 1)^T
	d_GD = np.sqrt((x1_GD + 1.0) ** 2 + x_GD[0] ** 2 + (x_GD[1] - 1.0) ** 2)
	print(' ')
	print('Gradient Descent Distance = ' + str(d_GD))
	print(' ')

	# Plot method convergence
	fig = plt.figure(num=2)
	plt.semilogy(np.linspace(1, n_GD, n_GD), eps_GD, 'bD--', np.linspace(1, n_N, n_N), eps_N, 'rD--')
	plt.grid(b=True, which='both', axis='y')
	plt.title('t = 0.5')
	plt.ylabel('error')
	plt.xlabel('# of Iterations')
	fig.legend(['Gradient Descent', 'Newtons Method'])

	# Gradient descent w/ inexact line search with t = 0.3
	x_GD, n_GD, eps_GD = GD_inexact(0.3, 1.0, np.array([[10.0], [10.0]]), 0.000001)
	x1_GD = -2.0 * x_GD[0] - 3.0 * x_GD[1] + 1

	print('t = ' + str(0.3))
	print('x1 = ' + str(x1_GD))
	print('x2 = ' + str(x_GD[0]))
	print('x3 = ' + str(x_GD[1]))

	# Determine distance of each solution to desired point (-1, 0, 1)^T
	d_GD = np.sqrt((x1_GD + 1.0) ** 2 + x_GD[0] ** 2 + (x_GD[1] - 1.0) ** 2)
	print(' ')
	print('Gradient Descent Distance = ' + str(d_GD))
	print(' ')

	# Plot method convergence
	fig = plt.figure(num=3)
	plt.semilogy(np.linspace(1, n_GD, n_GD), eps_GD, 'bD--', np.linspace(1, n_N, n_N), eps_N, 'rD--')
	plt.grid(b=True, which='both', axis='y')
	plt.title('t = 0.3')
	plt.ylabel('error')
	plt.xlabel('# of Iterations')
	fig.legend(['Gradient Descent', 'Newtons Method'])
# Out:
# Gradient Descent Optimization Complete
# # of Iterations: 18
# t = 1.0
# x1 = [-0.71115205]
# x2 = [0.08780133]
# x3 = [0.51184979]
# Newton Optimization Complete
# # of Iterations: 2
# x1 = [-1.07142857]
# x2 = [-0.14285714]
# x3 = [0.78571429]
#
# Gradient Descent Distance = [0.5739624]
# Newtons Method Distance = [0.26726124]
#
# Gradient Descent Optimization Complete
# # of Iterations: 36
# t = 0.5
# x1 = [-1.0717683]
# x2 = [-0.14153326]
# x3 = [0.78494494]
#
# Gradient Descent Distance = [0.26726584]
#
# Gradient Descent Optimization Complete
# # of Iterations: 41
# t = 0.3
# x1 = [-1.07105534]
# x2 = [-0.14219579]
# x3 = [0.78514897]
#
# Gradient Descent Distance = [0.26726292]

# %% [markdown]
# I initally started with the initial point $\mathrm{x_{0}}=\begin{bmatrix}0\\0\end{bmatrix}$. For the gradient descent method, I initially started with $\mathrm{t=1}$. This value of t showed significant differences in the x values of the solution when compared to Newton's method. When looking at the Euclidean distance between our solution point on the plane and the target point, at $\mathrm{t=1}$, the solution given by the gradient descent method is nearly double that of the solution given by Newton's method.
#
# I then tried $\mathrm{t=0.5}$ and $\mathrm{t=0.3}$. With these values, the gradient descent method gave a solution very similar to Newton's method. In order to achieve this solution, the gradient descent method required 22 and 29 iterations, respectively. In comparison, Newton's method only required 2 iterations. This obviously makes Newton's method ideal for this problem. But we must also realize the Newton's method requires the calculation of the Hessian and it's inverse. For this problem that is relatively inexpensive, but for much larger and more complex problem this could become a serious issue.
#
# Testing the inital guess, I next tried $\mathrm{x_{2}=0}$ and $\mathrm{x_{3}=1}$. I chose these points as they were closer to the solution values. What I found was that Newton's method performed the same and still required 2 iterations. For the gradient descent, at $\mathrm{t=1.0}$, the solution was still significantly different than Newton's but better than with the previous initial guess and required 6 iterations. When tested with $\mathrm{t=0.5}$ and $\mathrm{t=0.3}$, the gradient descent solution with very similar to Newton's method and required 6 and 5 iterations respectively. This is a significant improvement in performance in terms of the number of iterations.
#
# I also tried and inital guess of $\mathrm{x_{2}=10}$ and $\mathrm{x_{3}=10}$ since this point was signficantly further from the solution. I saw the same trends as before. Newton's method required only 2 iterations yet again. The gradient descent required significantly more to achieve a good solution. Thus, suggesting that the gradient descent method is very sensitive to the initial guess. Meanwhile, Newton's method does not seem to be sensitive at all to the initial guess, at least for this specific problem.

# %% [markdown]
# # Problem 3

# %% [markdown]
# # Problem 4

# %% [markdown]
# $\mathrm{\underset{p}{min:}\;\;\underset{k}{max}\left\{ h\left(\mathbf{a}_{k}^{T}\mathbf{p},I_{t}\right)\right\} }$
#
# s.t.
#
# $\mathrm{0\leq p_{i}\leq p_{max}}$
#
# Given the function, $\mathrm{h\left(I,I_{t}\right)=\left\{ \begin{array}{cc}
# \frac{I_{t}}{I}, & I\leq I_{t}\\
# \frac{I}{I_{t}}, & I_{t}\leq I
# \end{array}\right.}$

# %% [markdown]
# ### a)

# %% [markdown]
# Given h, we can plot h for $\mathrm{0\leq I\leq10}$, as an example. We know from the context of the problem that I is light intensity and $\mathrm{I_{t}}$ is the target light intensity. As such, we know that I and $\mathrm{I_{t}}$ will never be negative.

# %% [markdown]
# ![plot%204a.png](attachment:plot%204a.png)

# %% [markdown]
# As we can see from the plot, h(I,It) is convex and has a minimum value of 1. This minimum value occurs when I = $\mathrm{I_{t}}$. So we know that h is convex w.r.t. I and $\mathrm{I_{t}}$. To determine if our optimization problem is convex, we need to determine if h is convex w.r.t. $\mathrm{a^{T}p}$. More specifically, we need to determine if h is convex w.r.t. to p. To do this, we need to look at the gradient and the Hessian of h.
#
#
# $\mathrm{\nabla_{p}h\left(a^{T}p,I_{t}\right)=\frac{dh}{dI}\frac{\partial\left(a^{T}p\right)}{\partial p}=\nabla_{I}h\cdot a}$
#
# $\mathrm{H\left(h\right)=\frac{\partial^{2}h}{\partial p^{2}}=\frac{\partial}{\partial p}\left(\nabla_{I}h\cdot a\right)=\frac{d\left(\nabla_{I}h\right)}{I}\frac{\partial\left(a^{T}p\right)}{\partial p}\cdot a^{T}=\nabla_{I}^{2}h\,a\,a^{T}}$
#
# As we showed in the plot above, h is convex, thus $\mathrm{\nabla_{I}^{2}h\geq0}$, making it p.s.d. We showed in class that the matrix, $\mathrm{a\,a^{T}}$, is also p.s.d. Therefore, h w.r.t. p is convex.
#
# In class, we also showed that, if $\mathrm{f_{1},f_{2}}$ are convex then, $\mathrm{max\begin{Bmatrix}f_{1} & f_{2}\end{Bmatrix}}$ is convex. Therefore, our optimization problem **is convex**, since our only constraint is also convex.

# %% [markdown]
# ### b)

# %% [markdown]
# Here are optimization problem has the constraint slightly altered and is now,
#
# $\mathrm{0\leq p_{i}<10}$
#
# The optimization problem is still convex as in part a. In part a we saw from the plot of h(I,It), that part of h is strictly convex and part is just convex. Specifically,
#
# $\mathrm{I\leq I_{t}}$, h is strictly convex
# $\mathrm{I\geq I_{t}}$, h is convex, p.s.d.
#
# We saw from the plot, that the minimum value of h occurs when $\mathrm{I=I_{t}}$.
#
# Thus, when $\mathrm{I\leq I_{t}}$, h is always decreasing until $\mathrm{I=I_{t}}$. When $\mathrm{I\geq I_{t}}$, the negative gradient of h will cause the optimization to always slope down towards $\mathrm{I=I_{t}}$. This combination suggests that this problem **will have a unique solution**, specifically a solution that gives $\mathrm{I=I_{t}}$.

# %% [markdown]
# ### c)

# %% [markdown]
# As in part b, we again have the same optimization function as in part a. The difference here is that there is now an additional constraint.
#
# $\mathrm{\underset{p}{min:}\;\;\underset{k}{max}\left\{ h\left(\mathbf{a}_{k}^{T}\mathbf{p},I_{t}\right)\right\} }$
#
# s.t.
#
# $\mathrm{0\leq p_{i}\leq p_{max}}$
#
# $\mathrm{b_{i}\equiv\left\{ \begin{array}{cc}
# 1, & p_{i}>0\\
# 0, & p_{i}=0
# \end{array}\right.}$
#
# $\mathrm{\sum_{i=1}^{n}b_{i}\leq10}$
#
# Here, I **do not** believe that this optimization problem is guaranteed to have a unique solution. The optimal solution will still be one that gives $\mathrm{I=I_{t}}$. However, it may be possible even likely, that there are multiple combinations of up to 10 lamps in combination with the m mirrors that can acheive $\mathrm{I=I_{t}}$. In fact, it might be possible that this additional constraint limits our solution domain to the point that **no solution** will be able to achieve $\mathrm{I=I_{t}}$. If this is the case, than our function may look like the following,

# %% [markdown]
# ![plot%204c.png](attachment:plot%204c.png)

# %% [markdown]
# We can see, that as expected, our function is still convex, however there are multiple soltions that minimize h(I,It). Yet, if this is the case, our multiple solutions will indeed minimize h(I,It), but they would not be able to achieve $\mathrm{I=I_{t}}$.

# %% [markdown]
# # Problem 5

# %% [markdown]
# Given, $\mathrm{c^{*}\left(y\right)=\underset{x}{max}\left\{ xy-c\left(x\right)\right\} }$, to show if this function $\mathrm{c^{x}\left(y\right)}$ is convex w.r.t. y, we need to calculate the gradient and Hessian w.r.t. y.
#
# $\mathrm{\nabla_{y}c^{*}\left(y\right)=\nabla_{y}\left(xy-c\left(x\right)\right)=x}$
#
# $\mathrm{H\left(c^{*}\left(y\right)\right)=\frac{d^{2}}{dy^{2}}\left(c^{*}\left(y\right)\right)=\frac{d}{dy}\left(\nabla_{y}c^{*}\left(y\right)\right)=\frac{d}{dy}\left(x\right)=0}$
#
# Since the Hessian is zero and $\mathrm{c^{*}\left(y\right)\in c^{1}}$, this suggests that our function is a linear function w.r.t. y. We know that linear functions are convex, so $\mathrm{c^{x}\left(y\right)}$ **is convex w.r.t. y.**
#
# Looking at the given function, this intuitively makes sense. $\mathrm{c\left(x\right)}$ will just be a scalar value that is dependent on a given x. Thus, given a y, we should always be able to follow the gradient to a value of x which will maximize the profit under a given set of constraints.
